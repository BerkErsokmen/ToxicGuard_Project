# %% [markdown]
# # 🛡️ ToxicGuard — Colab Notebook (Local Runtime)
# **FAZ 4: Model Değerlendirme + FAZ 1: EDA Grafikleri**
#
# Bu notebook VS Code Colab extension'ı ile **yerel bilgisayara bağlı** çalışır.
# Google Drive mount'a gerek yok — dosyalar doğrudan `mezuniyet_proje/` klasöründen okunur ve oraya yazılır.

# %%
# ================================================
# HÜCRE 1 — Proje Yolu Ayarla
# ================================================
import os
from google.colab import drive
drive.mount('/content/drive')

BASE = '/content/drive/MyDrive/ToxicGuard'  # Drive'da oluşturduğun klasör
MODELS_DIR  = os.path.join(BASE, 'models')
DATA_DIR    = os.path.join(BASE, 'data')
RESULTS_DIR = os.path.join(BASE, 'reports', 'model_results')
EDA_DIR     = os.path.join(BASE, 'reports', 'eda_plots')
os.makedirs(RESULTS_DIR, exist_ok=True)
os.makedirs(EDA_DIR, exist_ok=True)
print("✅ Drive bağlandı!")
# Out:
# Mounted at /content/drive
# ✅ Drive bağlandı!

# %%
# ================================================
# HÜCRE 2 — Kütüphaneleri Kur (ilk çalıştırmada)
# ================================================
# !pip install xgboost scikit-learn matplotlib seaborn wordcloud nltk joblib --quiet

import nltk
nltk.download('stopwords', quiet=True)
print('✅ Kütüphaneler hazır!')
# Out:
# ✅ Kütüphaneler hazır!

# %%
# ================================================
# HÜCRE 3 — İmportlar ve Sabitler
# ================================================
import json, time, warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.dpi'] = 120
import seaborn as sns
from wordcloud import WordCloud
from nltk.corpus import stopwords
from sklearn.metrics import (
    f1_score, precision_score, recall_score, roc_auc_score
)

LABEL_COLS = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
LABEL_TR   = {
    'toxic': 'Toksik', 'severe_toxic': 'Ağır Toksik', 'obscene': 'Müstehcen',
    'threat': 'Tehdit', 'insult': 'Hakaret', 'identity_hate': 'Kimlik Nefreti'
}
STOP_WORDS = set(stopwords.words('english'))
sns.set_theme(style='darkgrid', palette='muted')

print('✅ Hazır!')
# Out:
# ✅ Hazır!

# %%
# ================================================
# HÜCRE 4 — Test Verisi ve Modelleri Yükle
# ================================================
print('📦 Test verisi yükleniyor...')
X_test = joblib.load(os.path.join(DATA_DIR, 'X_test.pkl'))
y_test = joblib.load(os.path.join(DATA_DIR, 'y_test.pkl'))
print(f'   X_test: {X_test.shape},  y_test: {y_test.shape}')

MODEL_FILES = {
    'Logistic Regression': 'logistic_regression.pkl',
    'SVM':                 'svm_model.pkl',
    'XGBoost':             'xgboost_model.pkl',
}

# Random Forest varsa ekle (büyük dosya, yüklenmesi uzun sürer)
rf_path = os.path.join(MODELS_DIR, 'random_forest.pkl')
if os.path.exists(rf_path):
    MODEL_FILES['Random Forest'] = 'random_forest.pkl'
    print('   Random Forest bulundu, eklendi.')
else:
    print('   ⚠️ random_forest.pkl bulunamadı, atlanıyor.')

print('\n🤖 Modeller yükleniyor...')
models = {}
for name, fname in MODEL_FILES.items():
    path = os.path.join(MODELS_DIR, fname)
    if os.path.exists(path):
        models[name] = joblib.load(path)
        print(f'   ✅ {name}')
    else:
        print(f'   ❌ {name} bulunamadı: {path}')

print(f'\nToplam {len(models)} model yüklendi.')
# Out:
# 📦 Test verisi yükleniyor...
#    X_test: (31897, 50000),  y_test: (31897, 6)
#    Random Forest bulundu, eklendi.
#
# 🤖 Modeller yükleniyor...
#    ✅ Logistic Regression
#    ✅ SVM
#    ✅ XGBoost
#    ✅ Random Forest
#
# Toplam 4 model yüklendi.

# %%
# ================================================
# HÜCRE 5 — FAZ 4: Model Değerlendirme
# ================================================
all_results = []

for model_name, model in models.items():
    print(f'\n🔍 {model_name} değerlendiriliyor...')
    start = time.time()

    y_pred = model.predict(X_test)

    # Olasılık skoru (SVM için decision_function)
    try:
        y_prob = model.predict_proba(X_test)
    except AttributeError:
        df_vals = model.decision_function(X_test)
        y_prob = 1 / (1 + np.exp(-df_vals))

    elapsed = time.time() - start

    f1_micro   = f1_score(y_test, y_pred, average='micro', zero_division=0)
    f1_macro   = f1_score(y_test, y_pred, average='macro', zero_division=0)
    prec_macro = precision_score(y_test, y_pred, average='macro', zero_division=0)
    rec_macro  = recall_score(y_test, y_pred, average='macro', zero_division=0)
    try:
        auc = roc_auc_score(y_test, y_prob, average='macro', multi_class='ovr')
    except Exception:
        auc = 0.0

    y_test_arr = np.array(y_test)
    per_label = {
        col: {
            'f1':        round(f1_score(y_test_arr[:, i], y_pred[:, i], zero_division=0), 4),
            'precision': round(precision_score(y_test_arr[:, i], y_pred[:, i], zero_division=0), 4),
            'recall':    round(recall_score(y_test_arr[:, i], y_pred[:, i], zero_division=0), 4),
        }
        for i, col in enumerate(LABEL_COLS)
    }

    result = {
        'model':      model_name,
        'f1_micro':   round(f1_micro, 4),
        'f1_macro':   round(f1_macro, 4),
        'precision':  round(prec_macro, 4),
        'recall':     round(rec_macro, 4),
        'roc_auc':    round(auc, 4),
        'eval_time_s':round(elapsed, 1),
        'per_label':  per_label
    }
    all_results.append(result)
    print(f'   F1 Micro: {f1_micro:.4f}  |  F1 Macro: {f1_macro:.4f}  |  ROC-AUC: {auc:.4f}  |  Süre: {elapsed:.1f}s')

print('\n✅ Değerlendirme tamamlandı!')
# Out:
# 🔍 Logistic Regression değerlendiriliyor...
#    F1 Micro: 0.6830  |  F1 Macro: 0.5643  |  ROC-AUC: 0.9816  |  Süre: 0.1s
#
# 🔍 SVM değerlendiriliyor...
#    F1 Micro: 0.7038  |  F1 Macro: 0.5187  |  ROC-AUC: 0.9731  |  Süre: 0.2s
#
# 🔍 XGBoost değerlendiriliyor...
#    F1 Micro: 0.7085  |  F1 Macro: 0.5987  |  ROC-AUC: 0.9669  |  Süre: 14.7s
#
# 🔍 Random Forest değerlendiriliyor...
#    F1 Micro: 0.5905  |  F1 Macro: 0.3803  |  ROC-AUC: 0.9642  |  Süre: 64.5s
#
# ✅ Değerlendirme tamamlandı!

# %%
# ================================================
# HÜCRE 6 — Sonuçları Kaydet (JSON + CSV)
# ================================================
json_path = os.path.join(RESULTS_DIR, 'model_comparison.json')
with open(json_path, 'w', encoding='utf-8') as f:
    json.dump(all_results, f, ensure_ascii=False, indent=2)

rows = [{
    'Model':      r['model'],
    'F1 Micro':   r['f1_micro'],
    'F1 Macro':   r['f1_macro'],
    'Precision':  r['precision'],
    'Recall':     r['recall'],
    'ROC-AUC':    r['roc_auc'],
    'Süre (sn)':  r['eval_time_s'],
} for r in all_results]

df_comp = pd.DataFrame(rows).sort_values('F1 Macro', ascending=False).reset_index(drop=True)
csv_path = os.path.join(RESULTS_DIR, 'model_comparison.csv')
df_comp.to_csv(csv_path, index=False, encoding='utf-8-sig')

print(f'✅ JSON kaydedildi → {json_path}')
print(f'✅ CSV  kaydedildi → {csv_path}')
print()
print('📊 Karşılaştırma Tablosu:')
display(df_comp)
# Out:
# ✅ JSON kaydedildi → /content/drive/MyDrive/ToxicGuard/reports/model_results/model_comparison.json
# ✅ CSV  kaydedildi → /content/drive/MyDrive/ToxicGuard/reports/model_results/model_comparison.csv
#
# 📊 Karşılaştırma Tablosu:
#                  Model  F1 Micro  F1 Macro  Precision  Recall  ROC-AUC  \
# 0              XGBoost    0.7085    0.5987     0.5527  0.6658   0.9669
# 1  Logistic Regression    0.6830    0.5643     0.4520  0.8185   0.9816
# 2                  SVM    0.7038    0.5187     0.7198  0.4230   0.9731
# 3        Random Forest    0.5905    0.3803     0.5275  0.3262   0.9642
#
#    Süre (sn)
# 0       14.7
# 1        0.1
# 2        0.2
# 3       64.5

# %%
# ================================================
# HÜCRE 7 — FAZ 1: EDA Grafiklerini Üret
# ================================================
print('📊 Temizlenmiş veri yükleniyor...')
df = pd.read_csv(os.path.join(DATA_DIR, 'gercek_temizlenmis_veri.csv'))
df = df.dropna(subset=['cleaned_text'])
df = df[df['cleaned_text'].str.strip() != ''].reset_index(drop=True)
df['word_count'] = df['cleaned_text'].apply(lambda x: len(str(x).split()))
print(f'   {len(df):,} satır yüklendi.')
# Out:
# 📊 Temizlenmiş veri yükleniyor...
#    159,484 satır yüklendi.

# %%
# GRAFİK 1 — Etiket Dağılımı
fig, ax = plt.subplots(figsize=(10, 5))
counts = df[LABEL_COLS].sum().sort_values(ascending=False)
bars = ax.bar([LABEL_TR[c] for c in counts.index], counts.values,
              color=sns.color_palette('viridis', len(LABEL_COLS)))
ax.bar_label(bars, fmt='%d', fontsize=10)
ax.set_title('Etiket Dağılımı — Toksik Yorum Sayıları', fontsize=14, fontweight='bold')
ax.set_ylabel('Yorum Sayısı')
plt.tight_layout()
plt.savefig(os.path.join(EDA_DIR, '01_label_distribution.png'), bbox_inches='tight')
plt.show()
print('✅ 01_label_distribution.png')
# Out:
# ✅ 01_label_distribution.png

# %%
# GRAFİK 2 — Sınıf Dengesizliği
fig, axes = plt.subplots(2, 3, figsize=(14, 7))
axes = axes.flatten()
for i, col in enumerate(LABEL_COLS):
    vc = df[col].value_counts()
    axes[i].pie(vc.values, labels=['Zararsız', 'Toksik'],
                autopct='%1.1f%%', colors=['#2ecc71', '#e74c3c'], startangle=90)
    axes[i].set_title(LABEL_TR[col], fontweight='bold')
fig.suptitle('Sınıf Dengesizliği', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EDA_DIR, '02_class_imbalance.png'), bbox_inches='tight')
plt.show()
print('✅ 02_class_imbalance.png')
# Out:
# ✅ 02_class_imbalance.png

# %%
# GRAFİK 3 — Etiket Korelasyonu
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(df[LABEL_COLS].corr(), annot=True, fmt='.2f', cmap='coolwarm',
            xticklabels=[LABEL_TR[c] for c in LABEL_COLS],
            yticklabels=[LABEL_TR[c] for c in LABEL_COLS],
            vmin=-1, vmax=1, center=0, ax=ax, linewidths=0.5)
ax.set_title('Etiketler Arası Pearson Korelasyonu', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EDA_DIR, '03_label_correlation.png'), bbox_inches='tight')
plt.show()
print('✅ 03_label_correlation.png')
# Out:
# ✅ 03_label_correlation.png

# %%
# GRAFİK 4 — Metin İstatistikleri
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(df[df['toxic']==0]['word_count'].clip(0,100), bins=50, alpha=0.7, label='Zararsız', color='#2ecc71')
axes[0].hist(df[df['toxic']==1]['word_count'].clip(0,100), bins=50, alpha=0.7, label='Toksik',   color='#e74c3c')
axes[0].set_title('Kelime Sayısı Dağılımı (0-100)', fontweight='bold')
axes[0].set_xlabel('Kelime Sayısı')
axes[0].legend()

avgs = {LABEL_TR[c]: df[df[c]==1]['word_count'].mean() for c in LABEL_COLS}
avgs['Zararsız'] = df[df['toxic']==0]['word_count'].mean()
axes[1].barh(list(avgs.keys()), list(avgs.values()),
             color=['#e74c3c']*len(LABEL_COLS)+['#2ecc71'])
axes[1].set_title('Ortalama Kelime Sayısı (Kategori Bazlı)', fontweight='bold')

plt.suptitle('Metin İstatistikleri', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EDA_DIR, '04_text_statistics.png'), bbox_inches='tight')
plt.show()
print('✅ 04_text_statistics.png')
# Out:
# ✅ 04_text_statistics.png

# %%
# GRAFİK 5 — Kelime Bulutları
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

toxic_text = ' '.join(df[df['toxic']==1]['cleaned_text'].dropna())
wc_toxic = WordCloud(width=700, height=400, background_color='#1a1a2e',
                     colormap='Reds', max_words=100, collocations=False)
wc_toxic.generate(toxic_text or 'no data')
axes[0].imshow(wc_toxic, interpolation='bilinear')
axes[0].axis('off')
axes[0].set_title('🔴 Toksik Yorumlar', fontweight='bold', fontsize=13)

safe_sample = df[df['toxic']==0]['cleaned_text'].dropna().sample(
    min(5000, (df['toxic']==0).sum()), random_state=42)
safe_text = ' '.join(safe_sample)
wc_safe = WordCloud(width=700, height=400, background_color='#0a2e1a',
                    colormap='Greens', max_words=100, collocations=False)
wc_safe.generate(safe_text or 'no data')
axes[1].imshow(wc_safe, interpolation='bilinear')
axes[1].axis('off')
axes[1].set_title('🟢 Zararsız Yorumlar', fontweight='bold', fontsize=13)

plt.suptitle('Kelime Bulutları', fontsize=15, fontweight='bold')
plt.tight_layout()
plt.savefig(os.path.join(EDA_DIR, '05_wordclouds.png'), bbox_inches='tight', facecolor='#111')
plt.show()
print('✅ 05_wordclouds.png')
# Out:
# ✅ 05_wordclouds.png

# %%
# GRAFİK 6 — Veri Seti Özet Tablosu
fig, ax = plt.subplots(figsize=(10, 5))
ax.axis('off')
summary_data = [
    ['Toplam Yorum Sayısı',           f'{len(df):,}'],
    ['Zararsız Yorum',                f'{(df["toxic"]==0).sum():,}  ({(df["toxic"]==0).mean():.1%})'],
    ['En Az 1 Etiket Toksik',         f'{(df[LABEL_COLS].sum(axis=1)>0).sum():,}'],
    ['Ortalama Kelime Sayısı',         f'{df["word_count"].mean():.1f}'],
    ['Etiket Kategorisi',             '6'],
    ['En Yaygın Kategori',            f'{LABEL_TR[df[LABEL_COLS].sum().idxmax()]}  ({df[LABEL_COLS].sum().max():,})'],
    ['En Nadir Kategori',             f'{LABEL_TR[df[LABEL_COLS].sum().idxmin()]}  ({df[LABEL_COLS].sum().min():,})'],
]
table = ax.table(cellText=summary_data, colLabels=['Metrik', 'Değer'],
                 cellLoc='left', loc='center', colWidths=[0.55, 0.45])
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 2.0)
ax.set_title('Veri Seti Özet İstatistikleri', fontsize=15, fontweight='bold', pad=20)
plt.tight_layout()
plt.savefig(os.path.join(EDA_DIR, '06_data_summary.png'), bbox_inches='tight')
plt.show()
print('✅ 06_data_summary.png')
print()
print('🎉 Tüm dosyalar reports/ klasörüne kaydedildi. Artık Streamlit çalıştırabilirsin!')
# Out:
# ✅ 06_data_summary.png
#
# 🎉 Tüm dosyalar reports/ klasörüne kaydedildi. Artık Streamlit çalıştırabilirsin!

# %%
from collections import Counter

# En sık geçen 100 kelimeyi gör (toksik yorumlar)
toxic_words = ' '.join(df[df['toxic']==1]['cleaned_text'].dropna()).split()
print("TOKSIK TOP 100:")
print(Counter(toxic_words).most_common(100))

# Zararsız yorumlarda da geçen ama anlamsız kelimeler
safe_words = ' '.join(df[df['toxic']==0]['cleaned_text'].dropna().sample(10000, random_state=42)).split()
print("\nZARARSIZ TOP 100:")
print(Counter(safe_words).most_common(100))
# Out:
# TOKSIK TOP 100:
# [('fuck', 9935), ('shit', 3621), ('like', 3512), ('wikipedia', 3433), ('nigger', 3299), ('fucking', 3289), ('suck', 3235), ('ass', 2940), ('u', 2881), ('go', 2864), ('hate', 2631), ('get', 2300), ('gay', 2238), ('know', 2201), ('page', 2145), ('die', 2082), ('faggot', 2017), ('fat', 1970), ('people', 1873), ('moron', 1862), ('bitch', 1785), ('hi', 1691), ('cunt', 1541), ('one', 1527), ('sucks', 1443), ('stupid', 1439), ('stop', 1420), ('talk', 1410), ('article', 1390), ('pig', 1355), ('jew', 1350), ('dick', 1303), ('user', 1264), ('penis', 1238), ('think', 1236), ('wiki', 1223), ('want', 1220), ('bullshit', 1139), ('life', 1088), ('block', 1088), ('time', 1062), ('asshole', 1042), ('wanker', 1035), ('dont', 1029), ('would', 1021), ('fag', 1012), ('even', 1007), ('bark', 1001), ('balls', 999), ('right', 960), ('make', 952), ('idiot', 951), ('vandalism', 950), ('going', 947), ('sex', 946), ('cock', 940), ('edit', 935), ('please', 919), ('see', 918), ('little', 851), ('piece', 844), ('nipple', 825), ('really', 816), ('bad', 810), ('hey', 800), ('kill', 796), ('good', 793), ('hell', 789), ('aids', 783), ('eat', 773), ('dickhead', 763), ('bastard', 754), ('say', 742), ('fucker', 742), ('also', 737), ('care', 735), ('well', 727), ('admin', 723), ('shut', 721), ('back', 699), ('edits', 696), ('nothing', 692), ('way', 688), ('give', 678), ('damn', 678), ('faggots', 675), ('old', 666), ('freedom', 649), ('loser', 642), ('come', 641), ('take', 641), ('love', 640), ('blocked', 629), ('need', 627), ('fucksex', 624), ('said', 622), ('yourselfgo', 621), ('rape', 606), ('big', 606), ('tell', 598)]
#
# ZARARSIZ TOP 100:
# [('article', 3668), ('wikipedia', 3153), ('page', 3041), ('talk', 2501), ('please', 1949), ('would', 1930), ('one', 1896), ('like', 1670), ('see', 1382), ('also', 1375), ('think', 1239), ('use', 1216), ('edit', 1181), ('know', 1163), ('people', 1131), ('articles', 1110), ('may', 1027), ('time', 972), ('thanks', 960), ('image', 882), ('user', 866), ('even', 852), ('make', 815), ('good', 814), ('deletion', 786), ('information', 774), ('well', 764), ('wp', 763), ('best', 762), ('tacos', 761), ('could', 755), ('hi', 728), ('first', 704), ('get', 702), ('help', 690), ('source', 684), ('way', 677), ('name', 674), ('thank', 670), ('sources', 670), ('want', 669), ('editing', 659), ('say', 654), ('pages', 643), ('used', 636), ('section', 634), ('edits', 632), ('much', 630), ('many', 629), ('teabag', 621), ('new', 620), ('need', 620), ('really', 614), ('discussion', 603), ('deleted', 599), ('made', 587), ('point', 573), ('link', 556), ('add', 555), ('find', 554), ('right', 520), ('work', 519), ('since', 503), ('look', 503), ('however', 500), ('read', 500), ('take', 493), ('list', 489), ('someone', 488), ('go', 484), ('something', 473), ('back', 472), ('fact', 468), ('blocked', 464), ('content', 457), ('said', 456), ('history', 451), ('case', 448), ('free', 445), ('sure', 441), ('utc', 437), ('still', 435), ('removed', 434), ('without', 431), ('added', 429), ('two', 429), ('might', 424), ('another', 423), ('going', 420), ('stop', 417), ('put', 415), ('welcome', 414), ('place', 396), ('editors', 396), ('note', 395), ('let', 395), ('already', 380), ('done', 379), ('using', 377), ('better', 377)]

# %%
from google.colab import files
import os, zipfile

# Zip oluştur
with zipfile.ZipFile('/content/toxicguard_reports.zip', 'w') as zf:
    reports_dir = '/content/toxicguard/reports'
    for root, dirs, fnames in os.walk(reports_dir):
        for fname in fnames:
            filepath = os.path.join(root, fname)
            zf.write(filepath, os.path.relpath(filepath, '/content/toxicguard'))

# İndir
files.download('/content/toxicguard_reports.zip')

# %%
import os

# Tüm dosyaları listele
for root, dirs, files in os.walk('/content'):
    for f in files:
        print(os.path.join(root, f))
# Out:
# /content/toxicguard_reports.zip
# /content/.config/.last_update_check.json
# /content/.config/active_config
# /content/.config/.last_survey_prompt.yaml
# /content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/default_configs.db
# /content/.config/gce
# /content/.config/config_sentinel
# /content/.config/logs/2026.04.02/13.31.06.236912.log
# /content/.config/logs/2026.04.02/13.30.52.812826.log
# /content/.config/logs/2026.04.02/13.30.17.544197.log
# /content/.config/logs/2026.04.02/13.30.40.372331.log
# /content/.config/logs/2026.04.02/13.31.07.077226.log
# /content/.config/logs/2026.04.02/13.30.51.422062.log
# /content/.config/configurations/config_default
# /content/drive/MyDrive/ODEV_HAZIRLAMA_KURALLARI_25122020.doc
# /content/drive/MyDrive/FINAL_ODEVI_HAZIRLAMA_KURALLARI_18012021.doc
# /content/drive/MyDrive/ODEV_HAZIRLAMA_KURALLARI_05052021_IKINCI (1).doc
# /content/drive/MyDrive/ODEV_HAZIRLAMA_KURALLARI_05052021_IKINCI.doc
# /content/drive/MyDrive/4000 Essential English Words 1-Key.pdf
# /content/drive/MyDrive/4000 Essential English Words 2-Key.pdf
# /content/drive/MyDrive/4000 Essential English Words 3-Key.pdf
# /content/drive/MyDrive/4000 essential english words 1.pdf
# /content/drive/MyDrive/4000 Essential English Words 2.pdf
# /content/drive/MyDrive/4000 Essential English Words 4-Key.pdf
# /content/drive/MyDrive/4000 Essential English Words 5-Key.pdf
# /content/drive/MyDrive/4000 Essential English Words 3.pdf
# /content/drive/MyDrive/4000 Essential English Words 6-Key.pdf
# /content/drive/MyDrive/4000 Essential English Words 5.pdf
# /content/drive/MyDrive/4000 Essential English Words 4.pdf
# /content/drive/MyDrive/4000 Essential English Words 6.pdf
# /content/drive/MyDrive/aaaaaaaaaaaaaaaaaaaaaaaaaaaa.docx
# /content/drive/MyDrive/lab rapor tr.docx
# /content/drive/MyDrive/BERKersokmen-CyberOps Associa-certificate.pdf
# /content/drive/MyDrive/Başlıksız Diyagram.drawio
# /content/drive/MyDrive/4_bbbb.drawio
# /content/drive/MyDrive/Berk_Ersökmen (1).pdf
# /content/drive/MyDrive/Berk_Ersökmen.dwg
# /content/drive/MyDrive/Berk_Ersökmen.xlsx
# /content/drive/MyDrive/Berk_Ersökmen.pdf
# /content/drive/MyDrive/Berk Ersökmen.png
# /content/drive/MyDrive/Berk_Ersökmen.psd
# /content/drive/MyDrive/transkript (1).pdf
# /content/drive/MyDrive/transkript.pdf
# /content/drive/MyDrive/mezuniyet_proje.zip
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled3.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled4.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled5.ipynb
# /content/drive/MyDrive/Colab Notebooks/ToxicGuard_Colab.ipynb
# /content/drive/MyDrive/Google AI Studio/CyberGuard Pro Dashboard
# /content/drive/MyDrive/Google AI Studio/Sana bir proje dosyası yüklüyorum, klasör yapısı en üstte yer alıyor. Lütfen tüm sorularımı bu pr...
# /content/drive/MyDrive/Google AI Studio/applet_access_history.json
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/PROJE_PLANI.md
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/.gitignore
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/.git
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/requirements.txt
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/app/app.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/data/X_test.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/data/y_test.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/data/X_train.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/data/gercek_temizlenmis_veri.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/data/y_train.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/docker/docker-compose.yml
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/docker/Dockerfile
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/datasset/sample_submission.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/datasset/test.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/datasset/test_labels.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/datasset/train.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/src/train.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/src/data_cleaning.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/src/utils.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/src/feature_extraction.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/src/__init__.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/src/predict.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/src/eda.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/reports/eda_plots/04_text_statistics.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/reports/eda_plots/05_wordclouds.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/reports/eda_plots/01_label_distribution.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/reports/eda_plots/03_label_correlation.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/reports/eda_plots/02_class_imbalance.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-08-18/reports/eda_plots/06_data_summary.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/.git
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/PROJE_PLANI.md
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/.gitignore
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/requirements.txt
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/src/train.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/src/predict.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/src/__init__.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/src/feature_extraction.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/src/utils.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/src/eda.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/src/data_cleaning.py
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/datasset/sample_submission.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/datasset/test.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/datasset/test_labels.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/datasset/train.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/docker/docker-compose.yml
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/docker/Dockerfile
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/reports/eda_plots/04_text_statistics.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/reports/eda_plots/05_wordclouds.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/reports/eda_plots/03_label_correlation.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/reports/eda_plots/01_label_distribution.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/reports/eda_plots/02_class_imbalance.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/reports/eda_plots/06_data_summary.png
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/data/X_test.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/data/X_train.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/data/gercek_temizlenmis_veri.csv
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/data/y_train.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/data/y_test.pkl
# /content/drive/MyDrive/mezuniyet_proje.worktrees/copilot-worktree-2026-03-27T08-11-21/app/app.py
# /content/drive/MyDrive/ToxicGuard/models/tfidf_vectorizer.pkl
# /content/drive/MyDrive/ToxicGuard/models/logistic_regression.pkl
# /content/drive/MyDrive/ToxicGuard/models/random_forest.pkl
# /content/drive/MyDrive/ToxicGuard/models/svm_model.pkl
# /content/drive/MyDrive/ToxicGuard/models/xgboost_model.pkl
# /content/drive/MyDrive/ToxicGuard/models/best_model.pkl
# /content/drive/MyDrive/ToxicGuard/data/gercek_temizlenmis_veri.csv
# /content/drive/MyDrive/ToxicGuard/data/y_test.pkl
# /content/drive/MyDrive/ToxicGuard/data/X_test.pkl
# /content/drive/MyDrive/ToxicGuard/reports/model_results/model_comparison.json
# /content/drive/MyDrive/ToxicGuard/reports/model_results/model_comparison.csv
# /content/drive/MyDrive/ToxicGuard/reports/eda_plots/01_label_distribution.png
# /content/drive/MyDrive/ToxicGuard/reports/eda_plots/02_class_imbalance.png
# /content/drive/MyDrive/ToxicGuard/reports/eda_plots/03_label_correlation.png
# /content/drive/MyDrive/ToxicGuard/reports/eda_plots/04_text_statistics.png
# /content/drive/MyDrive/ToxicGuard/reports/eda_plots/05_wordclouds.png
# /content/drive/MyDrive/ToxicGuard/reports/eda_plots/06_data_summary.png
# /content/sample_data/README.md
# /content/sample_data/anscombe.json
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_train.csv
# /content/sample_data/california_housing_test.csv
# /content/sample_data/mnist_train_small.csv
